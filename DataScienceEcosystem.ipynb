# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:a4bb0068-f9ba-469b-afc6-f688f5135124.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:3f4d74d2-ea11-4f34-aed5-382c6d87bc31.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. Julia
# 3. R

# %% [markdown]
# ![4-dslanguages.png](attachment:92679cd5-da58-456b-89f8-b45b905ea458.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. matplotlib
# 2. nltk
# 3. scipy
# 4. pandas

# %% [markdown]
# ![5-dslibraries.png](attachment:649cf2ca-18bf-4967-8f2d-13294d4cd4ed.png)

# %% [markdown]
# |Data Science tools|
# |------------------|
# |Python            |
# | R                |
# | Julia            |

# %% [markdown]
# ![6-dstools.png](attachment:3d54e340-0de8-490d-887a-cc144a7d0ddb.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# y = mx + b

# %% [markdown]
# ![7-introarithmetic.png](attachment:5d99e1b5-1493-4773-880f-d779a97e3417.png)

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:def92e72-b330-4513-8986-84ee97841476.png)

# %%
minutes = 200
minutes_to_hours = 60

minutes/minutes_to_hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:7d648df6-49be-4092-93e0-fd8dccc22119.png)

# %% [markdown]
# **Objectives:**
#
# - There are a total of 25 points possible for this final project.
# - Your grade will be based on the following Exercises:
# - Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)
# - Exercise 3 - Create a markdown cell for an introduction. (1 pt)
# - Exercise 4 - Create a markdown cell to list data science languages. (3 pts)
# - etc.

# %% [markdown]
# ![10-objectives.png](attachment:ee34c51b-7ce5-4f2c-802b-6626d51a5a0f.png)

# %% [markdown]
# ## Author:
# ## Arald Jean-Charles ##

# %% [markdown]
# ![11-authordetails.png](attachment:bf5166c0-ba66-4613-b99e-3bf461e5247c.png)
